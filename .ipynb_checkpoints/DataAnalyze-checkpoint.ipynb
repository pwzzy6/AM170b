# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
import warnings 
warnings.filterwarnings('ignore')

# %%
ar = pd.read_csv('AirQuality.csv',sep=';')
ar
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
# getting the numerical estimates of all the numerical column
ar.describe()
# Out:
#        PT08.S1(CO)     NMHC(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# count  9357.000000  9357.000000    9357.000000  9357.000000   9357.000000
# mean   1048.990061  -159.090093     894.595276   168.616971    794.990168
# std     329.832710   139.789093     342.333252   257.433866    321.993552
# min    -200.000000  -200.000000    -200.000000  -200.000000   -200.000000
# 25%     921.000000  -200.000000     711.000000    50.000000    637.000000
# 50%    1053.000000  -200.000000     895.000000   141.000000    794.000000
# 75%    1221.000000  -200.000000    1105.000000   284.000000    960.000000
# max    2040.000000  1189.000000    2214.000000  1479.000000   2683.000000
#
#            NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  Unnamed: 15  Unnamed: 16
# count  9357.000000   9357.000000  9357.000000          0.0          0.0
# mean     58.148873   1391.479641   975.072032          NaN          NaN
# std     126.940455    467.210125   456.938184          NaN          NaN
# ...

# %%
#Dropping CO(GT) and Unnamed columns
ar.drop(['CO(GT)','Unnamed: 15','Unnamed: 16'],axis = 1,inplace = True)

# %%
#Formatting some object columns from strings to floats

ar.replace(to_replace=',',value='.',regex=True,inplace=True) 

for i in 'C6H6(GT) T RH AH'.split():
    ar[i] = pd.to_numeric(ar[i],errors='coerce')

# %%
#Replacing null data from -200 to NaN for posterior treatment

ar.replace(to_replace=-200,value=np.nan,inplace=True)

ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   PT08.S1(CO)    8991 non-null   float64
#  3   NMHC(GT)       914 non-null    float64
#  4   C6H6(GT)       8991 non-null   float64
#  5   PT08.S2(NMHC)  8991 non-null   float64
#  6   NOx(GT)        7718 non-null   float64
#  7   PT08.S3(NOx)   8991 non-null   float64
#  8   NO2(GT)        7715 non-null   float64
#  9   PT08.S4(NO2)   8991 non-null   float64
#  10  PT08.S5(O3)    8991 non-null   float64
#  11  T              8991 non-null   float64
#  12  RH             8991 non-null   float64
#  13  AH             8991 non-null   float64
# dtypes: float64(12), object(2)
# memory usage: 1.0+ MB

# %%
#Formatting Date and Time to datetime type

ar['Date'] = pd.to_datetime(ar['Date'],dayfirst=True) 

ar['Time'] = pd.to_datetime(ar['Time'],format= '%H.%M.%S' ).dt.time

ar.head()
# Out:
#         Date      Time  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0 2004-03-10  18:00:00       1360.0     150.0      11.9         1046.0
# 1 2004-03-10  19:00:00       1292.0     112.0       9.4          955.0
# 2 2004-03-10  20:00:00       1402.0      88.0       9.0          939.0
# 3 2004-03-10  21:00:00       1376.0      80.0       9.2          948.0
# 4 2004-03-10  22:00:00       1272.0      51.0       6.5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13.6  48.9
# 1    103.0        1174.0     92.0        1559.0        972.0  13.3  47.7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11.9  54.0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11.0  60.0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11.2  59.6
#
#        AH
# 0  0.7578
# 1  0.7255
# 2  0.7502
# 3  0.7867
# 4  0.7888

# %%
#Removing NMHC(GT) sensor due to amount of null values

ar.drop('NMHC(GT)', axis=1, inplace=True) 

ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   datetime64[ns]
#  1   Time           9357 non-null   object
#  2   PT08.S1(CO)    8991 non-null   float64
#  3   C6H6(GT)       8991 non-null   float64
#  4   PT08.S2(NMHC)  8991 non-null   float64
#  5   NOx(GT)        7718 non-null   float64
#  6   PT08.S3(NOx)   8991 non-null   float64
#  7   NO2(GT)        7715 non-null   float64
#  8   PT08.S4(NO2)   8991 non-null   float64
#  9   PT08.S5(O3)    8991 non-null   float64
#  10  T              8991 non-null   float64
#  11  RH             8991 non-null   float64
#  12  AH             8991 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(1)
# memory usage: 962.0+ KB

# %%
ar.drop(['CO(GT)']  ,axis=1, inplace=True, errors = 'ignore')
ar.drop(['NOx(GT)'] ,axis=1, inplace=True, errors = 'ignore')
ar.drop(['C6H6(GT)'],axis=1, inplace=True, errors = 'ignore')
ar.drop(['NO2(GT)'] ,axis=1, inplace=True, errors = 'ignore')
ar.head()
# Out:
#         Date      Time  PT08.S1(CO)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# 0 2004-03-10  18:00:00       1360.0         1046.0        1056.0
# 1 2004-03-10  19:00:00       1292.0          955.0        1174.0
# 2 2004-03-10  20:00:00       1402.0          939.0        1140.0
# 3 2004-03-10  21:00:00       1376.0          948.0        1092.0
# 4 2004-03-10  22:00:00       1272.0          836.0        1205.0
#
#    PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 0        1692.0       1268.0  13.6  48.9  0.7578
# 1        1559.0        972.0  13.3  47.7  0.7255
# 2        1555.0       1074.0  11.9  54.0  0.7502
# 3        1584.0       1203.0  11.0  60.0  0.7867
# 4        1490.0       1110.0  11.2  59.6  0.7888

# %%
ar = ar.dropna()
percent_NaN = []
columns = ar.columns
for col in columns:
    pNaN =  (ar[col].isna().sum()/ar.shape[0]) * 100 #sum NaN instances in each column. Divide by total rows
    percent_NaN.append(pNaN)
nan_percent_df = pd.DataFrame(percent_NaN,
                              index=columns,
                              columns=['%_NaN_in_Column']).sort_values('%_NaN_in_Column',ascending = False)
nan_percent_df
# Out:
#                %_NaN_in_Column
# Date                       0.0
# Time                       0.0
# PT08.S1(CO)                0.0
# PT08.S2(NMHC)              0.0
# PT08.S3(NOx)               0.0
# PT08.S4(NO2)               0.0
# PT08.S5(O3)                0.0
# T                          0.0
# RH                         0.0
# AH                         0.0

# %%
ar.info
# Out:
# <bound method DataFrame.info of            Date      Time  PT08.S1(CO)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# 0    2004-03-10  18:00:00       1360.0         1046.0        1056.0
# 1    2004-03-10  19:00:00       1292.0          955.0        1174.0
# 2    2004-03-10  20:00:00       1402.0          939.0        1140.0
# 3    2004-03-10  21:00:00       1376.0          948.0        1092.0
# 4    2004-03-10  22:00:00       1272.0          836.0        1205.0
# ...         ...       ...          ...            ...           ...
# 9352 2005-04-04  10:00:00       1314.0         1101.0         539.0
# 9353 2005-04-04  11:00:00       1163.0         1027.0         604.0
# 9354 2005-04-04  12:00:00       1142.0         1063.0         603.0
# 9355 2005-04-04  13:00:00       1003.0          961.0         702.0
# 9356 2005-04-04  14:00:00       1071.0         1047.0         654.0
#
#       PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 0           1692.0       1268.0  13.6  48.9  0.7578
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('AirQuality.csv',sep=";", decimal=",",header=0)

df.head()
df.drop(columns=['Unnamed: 15', 'Unnamed: 16'],inplace=True)
df.dropna(inplace=True)
df.replace(to_replace=-200,value=np.nan,inplace=True)

df.to_csv("uncleaned data.csv", index=False)
# df.drop(columns=['NMHC(GT)'],inplace=True)
# df.isna().sum()

# df.drop(columns=['C6H6(GT)'],inplace=True)
# df.drop(columns=['NOx(GT)'],inplace=True)
# df.drop(columns=['NO2(GT)'],inplace=True)
# df.drop(columns=['CO(GT)'],inplace=True)

# %%
col = ['PT08.S1(CO)','PT08.S2(NMHC)', 'PT08.S3(NOx)', 'PT08.S4(NO2)','PT08.S5(O3)', 'T', 'RH', 'AH']
df = df[col]
df[col].dtypes
df.describe()
# Out:
#        PT08.S1(CO)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  8991.000000    8991.000000   8991.000000   8991.000000  8991.000000
# mean   1099.833166     939.153376    835.493605   1456.264598  1022.906128
# std     217.080037     266.831429    256.817320    346.206794   398.484288
# min     647.000000     383.000000    322.000000    551.000000   221.000000
# 25%     937.000000     734.500000    658.000000   1227.000000   731.500000
# 50%    1063.000000     909.000000    806.000000   1463.000000   963.000000
# 75%    1231.000000    1116.000000    969.500000   1674.000000  1273.500000
# max    2040.000000    2214.000000   2683.000000   2775.000000  2523.000000
#
#                  T           RH           AH
# count  8991.000000  8991.000000  8991.000000
# mean     18.317829    49.234201     1.025530
# std       8.832116    17.316892     0.403813
# min      -1.900000     9.200000     0.184700
# 25%      11.800000    35.800000     0.736800
# ...

# %%
for i in col:
    df[i] = df[i].fillna(df[i].mean())
plt.figure(figsize=(5,5))
sns.boxplot(data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
# getting the quartile one and quartile 3 values of each column
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
# finally calculating the interquartile range IQR
IQR = Q3 - Q1
((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
# Out:
# PT08.S1(CO)      145
# PT08.S2(NMHC)     91
# PT08.S3(NOx)     278
# PT08.S4(NO2)     131
# PT08.S5(O3)      131
# T                 10
# RH                 0
# AH                 7
# dtype: int64

# %%
mask = (df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))
mask
# Out:
#       PT08.S1(CO)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           False          False         False         False        False
# 1           False          False         False         False        False
# 2           False          False         False         False        False
# 3           False          False         False         False        False
# 4           False          False         False         False        False
# ...           ...            ...           ...           ...          ...
# 9352        False          False         False         False        False
# 9353        False          False         False         False        False
# 9354        False          False         False         False        False
# 9355        False          False         False         False        False
# 9356        False          False         False         False        False
#
#           T     RH     AH
# 0     False  False  False
# ...

# %%
# now replacing all the outliers using the median of that particular column
for i in mask.columns:
    df[i].astype('float')
    temp = df[i].median()
    df.loc[mask[i], i] = temp

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
## do pca and clustering here
df.to_csv("cleaned data", index=False)

# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering, DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Load your data
data = pd.read_csv('uncleaned data.csv')

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data.select_dtypes(include=[float, int]))

# Apply PCA to reduce to 2 principal components
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)

# Hierarchical Clustering
hierarchical = AgglomerativeClustering(n_clusters=4)
hierarchical_clusters = hierarchical.fit_predict(pca_data)

# DBSCAN Clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_clusters = dbscan.fit_predict(pca_data)

# Gaussian Mixture Model Clustering
gmm = GaussianMixture(n_components=4, random_state=42)
gmm_clusters = gmm.fit_predict(pca_data)

# Create DataFrames for each clustering method
clustered_data_hierarchical = pd.DataFrame(pca_data, columns=['PCA1', 'PCA2'])
clustered_data_hierarchical['Cluster'] = hierarchical_clusters

clustered_data_dbscan = pd.DataFrame(pca_data, columns=['PCA1', 'PCA2'])
clustered_data_dbscan['Cluster'] = dbscan_clusters

clustered_data_gmm = pd.DataFrame(pca_data, columns=['PCA1', 'PCA2'])
clustered_data_gmm['Cluster'] = gmm_clusters

# Save the clustered data to new CSV files
# clustered_data_hierarchical.to_csv('/path/to/save/clustered_data_hierarchical.csv', index=False)
# clustered_data_dbscan.to_csv('/path/to/save/clustered_data_dbscan.csv', index=False)
# clustered_data_gmm.to_csv('/path/to/save/clustered_data_gmm.csv', index=False)

# Plot the results
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
scatter = plt.scatter(clustered_data_hierarchical['PCA1'], clustered_data_hierarchical['PCA2'], c=clustered_data_hierarchical['Cluster'], cmap='viridis', marker='o')
plt.title('Hierarchical Clustering Results')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.grid(True)

plt.subplot(1, 3, 2)
scatter = plt.scatter(clustered_data_dbscan['PCA1'], clustered_data_dbscan['PCA2'], c=clustered_data_dbscan['Cluster'], cmap='viridis', marker='o')
plt.title('DBSCAN Clustering Results')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.grid(True)

plt.subplot(1, 3, 3)
scatter = plt.scatter(clustered_data_gmm['PCA1'], clustered_data_gmm['PCA2'], c=clustered_data_gmm['Cluster'], cmap='viridis', marker='o')
plt.title('GMM Clustering Results')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(*scatter.legend_elements(), title="Clusters")
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Load your data
data = pd.read_csv('cleaned data')

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data.select_dtypes(include=[float, int]))

# Apply PCA to reduce to 2 principal components
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)

# Perform Hierarchical Clustering
hierarchical = AgglomerativeClustering(n_clusters=2)
hierarchical_clusters = hierarchical.fit_predict(pca_data)

# Create DataFrame for hierarchical clustering results
clustered_data_hierarchical = pd.DataFrame(pca_data, columns=['PCA1', 'PCA2'])
clustered_data_hierarchical['Cluster'] = hierarchical_clusters

# Save the clustered data to a new CSV file
clustered_file_path_hierarchical = 'cleanDataClustered.csv'
clustered_data_hierarchical.to_csv(clustered_file_path_hierarchical, index=False)

# Plot the results with different colors for each cluster and labeled PCA components
plt.figure(figsize=(10, 6))
scatter = plt.scatter(clustered_data_hierarchical['PCA1'], clustered_data_hierarchical['PCA2'], c=clustered_data_hierarchical['Cluster'], cmap='viridis', marker='o')

# Add titles and labels
plt.title('Hierarchical Clustering Results')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')

# Add a legend
plt.legend(*scatter.legend_elements(), title="Clusters")

# Show the plot
plt.grid(True)
plt.show()
